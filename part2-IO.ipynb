# %%
import pandas as pd

# %%
df = pd.read_csv('ZILLOW-S44_MRPST.csv')

# %%
df
# Out:
#           Date   Value
# 0   2018-04-30  1195.0
# 1   2018-03-31  1165.0
# 2   2018-02-28  1120.0
# 3   2018-01-31  1025.0
# 4   2017-12-31  1124.0
# 5   2017-11-30  1135.0
# 6   2017-10-31  1200.0
# 7   2017-09-30  1295.0
# 8   2017-08-31  1250.0
# 9   2017-07-31  1225.0
# 10  2017-06-30  1200.0
# 11  2017-05-31  1180.5

# %%
df.set_index('Date', inplace=True)

# %%
df
# Out:
#              Value
# Date
# 2018-04-30  1195.0
# 2018-03-31  1165.0
# 2018-02-28  1120.0
# 2018-01-31  1025.0
# 2017-12-31  1124.0
# 2017-11-30  1135.0
# 2017-10-31  1200.0
# 2017-09-30  1295.0
# 2017-08-31  1250.0
# 2017-07-31  1225.0
# 2017-06-30  1200.0
# 2017-05-31  1180.5

# %%
df.to_csv('newcsv2.csv')

# %%
df = pd.read_csv('newcsv2.csv')

# %%
df
# Out:
#           Date   Value
# 0   2018-04-30  1195.0
# 1   2018-03-31  1165.0
# 2   2018-02-28  1120.0
# 3   2018-01-31  1025.0
# 4   2017-12-31  1124.0
# 5   2017-11-30  1135.0
# 6   2017-10-31  1200.0
# 7   2017-09-30  1295.0
# 8   2017-08-31  1250.0
# 9   2017-07-31  1225.0
# 10  2017-06-30  1200.0
# 11  2017-05-31  1180.5

# %%
#eliminate the index column
df = pd.read_csv('newcsv2.csv', index_col = 0)

# %%
df
# Out:
#              Value
# Date
# 2018-04-30  1195.0
# 2018-03-31  1165.0
# 2018-02-28  1120.0
# 2018-01-31  1025.0
# 2017-12-31  1124.0
# 2017-11-30  1135.0
# 2017-10-31  1200.0
# 2017-09-30  1295.0
# 2017-08-31  1250.0
# 2017-07-31  1225.0
# 2017-06-30  1200.0
# 2017-05-31  1180.5

# %%
#rename the column
#every single column
df.columns = ['prices']

# %%
df
# Out:
#             prices
# Date
# 2018-04-30  1195.0
# 2018-03-31  1165.0
# 2018-02-28  1120.0
# 2018-01-31  1025.0
# 2017-12-31  1124.0
# 2017-11-30  1135.0
# 2017-10-31  1200.0
# 2017-09-30  1295.0
# 2017-08-31  1250.0
# 2017-07-31  1225.0
# 2017-06-30  1200.0
# 2017-05-31  1180.5

# %%
df.to_csv('newcsv3.csv')

# %%
#if the just want data
df.to_csv('newcsv4.csv', header = False)

# %%
#name the columns from a csv without column names
df = pd.read_csv('newcsv4.csv', names=['date', 'price'], index_col=0)

# %%
df
# Out:
#              price
# date
# 2018-04-30  1195.0
# 2018-03-31  1165.0
# 2018-02-28  1120.0
# 2018-01-31  1025.0
# 2017-12-31  1124.0
# 2017-11-30  1135.0
# 2017-10-31  1200.0
# 2017-09-30  1295.0
# 2017-08-31  1250.0
# 2017-07-31  1225.0
# 2017-06-30  1200.0
# 2017-05-31  1180.5

# %%
# convert to html
df.to_html('example.html')

# %%
df = pd.read_csv('newcsv4.csv', names=['date', 'prices'])
df.head()
# Out:
#          date  prices
# 0  2018-04-30  1195.0
# 1  2018-03-31  1165.0
# 2  2018-02-28  1120.0
# 3  2018-01-31  1025.0
# 4  2017-12-31  1124.0

# %%
#replace the name of a single column
df.rename(columns={'prices': 'PRICES'}, inplace = True)

# %%
df
# Out:
#           date  PRICES
# 0   2018-04-30  1195.0
# 1   2018-03-31  1165.0
# 2   2018-02-28  1120.0
# 3   2018-01-31  1025.0
# 4   2017-12-31  1124.0
# 5   2017-11-30  1135.0
# 6   2017-10-31  1200.0
# 7   2017-09-30  1295.0
# 8   2017-08-31  1250.0
# 9   2017-07-31  1225.0
# 10  2017-06-30  1200.0
# 11  2017-05-31  1180.5
